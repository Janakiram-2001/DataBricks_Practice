# %% [markdown]
# #### Important - There are 4 typical write modes and default is error.
# 1. overwrite
# 2. append
# 3. ignore
# 4. error

# %% [markdown]
# ####CSV Write Advanced Feature - Very Important, Important, Not Important (just try to know once for all)
# **Very Important:** path, mode, compression, sep, quote, escape, header   <br>
# **Important:** nullValue,quoteAll,dateFormat, timestampFormat, ignoreLeadingWhiteSpace, ignoreTrailingWhiteSpace,lineSep  <br>
# **Not Important:** escapeQuotes, charToEscapeQuoteEscaping, encoding, emptyValue

# %%
struct1="cid int,name string,amt double,dop string"
df1=spark.read.csv("/Volumes/we47/we47schema/we47volume/we47directory/malformeddata1.txt",header=False,sep=","
                                   ,comment='#',quote="'",escape='~',schema=struct1,multiLine=True,ignoreLeadingWhiteSpace=True,ignoreTrailingWhiteSpace=True)#permit malformed records and allow me to do a RCA (Root cause analysis)
df1.printSchema()
df1.show()

# %%
df1.write.csv(path="/Volumes/we47/we47schema/we47volume/we47directory/outputdata/csvout",mode="overwrite",header=True,sep="|",quote="'",escape='~',quoteAll=True)

# %%
#change the name data type to int instead of string
struct1="cid int,name int,amt double,dop string"
df1=spark.read.csv("/Volumes/we47/we47schema/we47volume/we47directory/malformeddata1.txt",header=False,sep=","
                                   ,comment='#',quote="'",escape='~',schema=struct1,multiLine=True,ignoreLeadingWhiteSpace=True,ignoreTrailingWhiteSpace=True)#permit malformed records and allow me to do a RCA (Root cause analysis)
df1.show()

# %%
df1.show()
df1.write.csv(path="/Volumes/we47/we47schema/we47volume/we47directory/outputdata/csvout1",mode="overwrite",header=True,sep="|",quote="&",escape='~',nullValue='not applicable',lineSep='$',compression='gzip')

spark.read.csv(path="/Volumes/we47/we47schema/we47volume/we47directory/outputdata/csvout1",header=True,sep="|",quote="&",escape='~',nullValue='not applicable',lineSep='$').show()

# %% [markdown]
# ####JSON Write Advanced Feature - Very Important, Important, Not Important (just try to know once for all)
# **Very Important:** path, mode, compression  <br>
# **Important:** dateFormat, timestampFormat, lineSep, ignoreNullFields  <br>
# **Not Important:** encoding

# %%
#change the name data type to int instead of string
struct1="cid int,name string,amt double,dop date"
df1=spark.read.csv("/Volumes/we47/we47schema/we47volume/we47directory/malformeddata1.txt",header=False,sep=","
                                   ,comment='#',quote="'",escape='~',schema=struct1,multiLine=True,ignoreLeadingWhiteSpace=True,ignoreTrailingWhiteSpace=True,dateFormat="yyyy-dd-MM")#permit malformed records and allow me to do a RCA (Root cause analysis)
df1.show()

# %%
df1.write.json("/Volumes/we47/we47schema/we47volume/we47directory/outputdata/jsonout",mode="overwrite",compression='gzip',lineSep='~',encoding='UTF-8',dateFormat='yyyy-dd-MM',ignoreNullFields=True)

# %% [markdown]
# %md
# ####Serialized Data format (orc/parquet/delta(we learn indepth in project)) Write Advanced Feature - Very Important, Important, Not Important (just try to know once for all)
# **Very Important:** path, mode, partitionBy, compression  <br>

# %%
df1.write.orc("/Volumes/we47/we47schema/we47volume/we47directory/outputdata/orcout",mode="overwrite",compression='none',partitionBy="dop")
df1.write.parquet("/Volumes/we47/we47schema/we47volume/we47directory/outputdata/parquetout",mode="overwrite",compression='none',partitionBy="dop")
df1.write.format("delta").save("/Volumes/we47/we47schema/we47volume/we47directory/outputdata/deltaout",mode="overwrite",partitionBy="dop")

# %%
dforc1=spark.read.orc("/Volumes/we47/we47schema/we47volume/we47directory/outputdata/orcout").where("dop='2025-12-18'")
dforc1.explain()
dforc1.show()
