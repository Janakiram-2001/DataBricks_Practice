# %%
dbutils.widgets.text("table_name","sampletable","please provide a table name");
tab_name = dbutils.widgets.get("table_name");
print(f"parameter passed is {tab_name}")
spark.sql(f"select * from we47.we47schema.{tab_name}").show(5)

# %%
dbutils.notebook.exit("success")
