# %%
import requests
import pandas as pd

response = requests.get("https://public.tableau.com/app/sample-data/mobile_os_usage.csv")
if response.status_code == 200:
    from io import StringIO
    pandasdf = pd.read_csv(StringIO(response.text))
    df = spark.createDataFrame(pandasdf)
    dbutils.fs.put("/Volumes/workspace/default/volumewe47_datalake/mobile_os_usage.csv",response.text,overwrite=True)
    spark.read.csv("/Volumes/workspace/default/volumewe47_datalake/mobile_os_usage.csv",header=True).display()

    # response = requests.get("http://worldclockapi.com/api/json/utc/now")
    # data = response.json()
    # display(data)
